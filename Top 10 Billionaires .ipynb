# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/kaggle/input/the-top-billionaires/The Top Billionaires.csv")
df
# Out:
#               NAME   2018   2019   2020   2021   2022
# 0        Elon Musk   19.9   22.3   24.6  151.0  219.0
# 1       Jeff Bezos  112.0  131.0  113.0  177.0  171.0
# 2  Bernard Arnault   72.0   76.0   76.0  150.0  158.0
# 3       Bill Gates   90.0   96.5   98.0  124.0  129.0
# 4   Warren Buffett   84.0   82.5   67.5   96.0  118.0
# 5       Larry Page   48.8   50.8   50.9   91.5  111.0
# 6      Sergey Brin   47.5   49.8   49.1   89.0  107.0
# 7    Larry Ellison   58.5   62.5   59.0   93.0  106.0
# 8    Steve Ballmer   38.4   41.2   52.7   68.7   91.4
# 9    Mukesh Ambani   40.1   50.0   36.8   84.5   90.7

# %% [markdown]
# # EDA

# %%
df.info
# Out:
# <bound method DataFrame.info of               NAME   2018   2019   2020   2021   2022
# 0        Elon Musk   19.9   22.3   24.6  151.0  219.0
# 1       Jeff Bezos  112.0  131.0  113.0  177.0  171.0
# 2  Bernard Arnault   72.0   76.0   76.0  150.0  158.0
# 3       Bill Gates   90.0   96.5   98.0  124.0  129.0
# 4   Warren Buffett   84.0   82.5   67.5   96.0  118.0
# 5       Larry Page   48.8   50.8   50.9   91.5  111.0
# 6      Sergey Brin   47.5   49.8   49.1   89.0  107.0
# 7    Larry Ellison   58.5   62.5   59.0   93.0  106.0
# 8    Steve Ballmer   38.4   41.2   52.7   68.7   91.4
# 9    Mukesh Ambani   40.1   50.0   36.8   84.5   90.7>

# %%
df.shape
# Out:
# (10, 6)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               NAME   2018   2019   2020   2021   2022
# 0        Elon Musk   19.9   22.3   24.6  151.0  219.0
# 1       Jeff Bezos  112.0  131.0  113.0  177.0  171.0
# 2  Bernard Arnault   72.0   76.0   76.0  150.0  158.0
# 3       Bill Gates   90.0   96.5   98.0  124.0  129.0
# 4   Warren Buffett   84.0   82.5   67.5   96.0  118.0
# 5       Larry Page   48.8   50.8   50.9   91.5  111.0
# 6      Sergey Brin   47.5   49.8   49.1   89.0  107.0
# 7    Larry Ellison   58.5   62.5   59.0   93.0  106.0
# 8    Steve Ballmer   38.4   41.2   52.7   68.7   91.4
# 9    Mukesh Ambani   40.1   50.0   36.8   84.5   90.7>

# %%
df.corr
# Out:
# <bound method DataFrame.corr of               NAME   2018   2019   2020   2021   2022
# 0        Elon Musk   19.9   22.3   24.6  151.0  219.0
# 1       Jeff Bezos  112.0  131.0  113.0  177.0  171.0
# 2  Bernard Arnault   72.0   76.0   76.0  150.0  158.0
# 3       Bill Gates   90.0   96.5   98.0  124.0  129.0
# 4   Warren Buffett   84.0   82.5   67.5   96.0  118.0
# 5       Larry Page   48.8   50.8   50.9   91.5  111.0
# 6      Sergey Brin   47.5   49.8   49.1   89.0  107.0
# 7    Larry Ellison   58.5   62.5   59.0   93.0  106.0
# 8    Steve Ballmer   38.4   41.2   52.7   68.7   91.4
# 9    Mukesh Ambani   40.1   50.0   36.8   84.5   90.7>

# %%
df.isnull().sum()
# Out:
# NAME    0
# 2018    0
# 2019    0
# 2020    0
# 2021    0
# 2022    0
# dtype: int64

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df,x="NAME",y="2018",label="2018")
sns.lineplot(data=df,x="NAME",y="2019",label="2019")
sns.lineplot(data=df,x="NAME",y="2020",label="2020")
sns.lineplot(data=df,x="NAME",y="2021",label="2021")
sns.lineplot(data=df,x="NAME",y="2022",label="2022")
# Out:
# <Axes: xlabel='NAME', ylabel='2018'>

# %% [markdown]
# ### As we can see Elon Musk Net Worth has went up drastically from 2018 - 2022

# %%
plt.figure(figsize=(20,12))
sns.barplot(data=df,y="2018",x="NAME",)
plt.title("The Rich in 2018",fontsize=30)
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.barplot(data=df,y="2019",x="NAME",)
plt.title("The Rich in 2019",fontsize=30)
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.barplot(data=df,y="2020",x="NAME",)
plt.title("The Rich in 2020",fontsize=30)
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.barplot(data=df,y="2021",x="NAME",)
plt.title("The Rich in 2021",fontsize=30)
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.barplot(data=df,y="2022",x="NAME",)
plt.title("The Rich in 2022",fontsize=30)
plt.show()

# %% [markdown]
# # Summary
# We have small DataSet for making Data Analysis about The Top Billionaires , the 10 richest people on the planet.
# Elon Musk - the first 3 year be less have money then he become rich person.
#
#
#
# In the year 2018 the highest persons
# 1- Jeff Bezos
# 2- Bill Gates
#
# In the year 2019 the highest persons
# 1- Jeff Bezos
# 2- Bill Gates
#
# In the year 2020 the highest persons
# 1- Jeff Bezos
# 2- Bill Gates
#
# In the year 2021 the highest persons
# 1- Jeff Bezos
# 2- Bernard Arnault
#
# In the year 2022 the highest persons
# 1- Elon Musk
# 2- Jeff Bezos
# Now the the highest persons = Elon Musk
