# %% [markdown]
# <a href="https://www.kaggle.com/code/deepakbaiju/walmart-dataset?scriptVersionId=132216923" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings 
warnings.filterwarnings('ignore')


# In[2]:


df=pd.read_csv("/kaggle/input/walmart-dataset/Walmart.csv")
df


# # EDA 

# In[3]:


df.head()


# In[4]:


df.tail()


# In[5]:


df.shape


# In[6]:


df.size


# In[7]:


df.ndim


# In[8]:


df.describe()


# In[9]:


df.info()


# In[10]:


df.isnull().sum()


# # Encoding 

# In[24]:


from sklearn.preprocessing import LabelEncoder
a=LabelEncoder()
df['Date']=a.fit_transform(df['Date'])
df


# In[25]:


from sklearn.preprocessing import MinMaxScaler
c=MinMaxScaler(feature_range=(1,3))
d=['Date','Weekly_Sales','Temperature','Fuel_Price','CPI','Unemployment']
for i in d:
           df[i]=c.fit_transform(df[[i]])
df


# In[45]:


df.corr()


# In[44]:


sns.heatmap(df.corr(),annot=True,cmap='PiYG')


# In[37]:


sns.pairplot(df)


# In[41]:


sns.histplot(data=df,x='Weekly_Sales',color='r')
plt.title('Weekly sales CPi')
plt.xlabel('weekly')


# In[42]:


plt.bar(data=df,color='g',x=['Weekly_Sales','CPi'],height=20)
plt.title('Sales')


# In[43]:


df


# 

# In[ ]:





# In[ ]:





# In[ ]:





# In[ ]:





# In[ ]:





# In[ ]:





# In[ ]:





# In[ ]:





# In[ ]:





# In[ ]:





# In[ ]:
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB
#       Store      Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  1.267606      1.794582             0     1.868297    1.100200
# 1         1  1.732394      1.793622             1     1.793933    1.076152
# 2         1  2.197183      1.777001             0     1.821722    1.042084
# ...
